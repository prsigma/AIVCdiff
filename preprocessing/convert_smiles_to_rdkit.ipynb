# %%
import pandas as pd
from descriptastorus.descriptors.DescriptorGenerator import MakeGenerator
import numpy as np
from joblib import Parallel, delayed
from tqdm.notebook import tqdm

# %%
# read BBBC021_v1_moa.csv file as pandas dataframe. The file can be downloaded from https://data.broadinstitute.org/bbbc/BBBC021/BBBC021_v1_compound.csv
smiles_df = pd.read_csv('/datasets/BBBC021/BBBC021_v1_compound.csv')

# %%
smiles_df
# Out:
#                compound                                             smiles
# 0                  DMSO                                                NaN
# 1             leupeptin  CC(C)C[C@H](NC(=O)C)C(=O)N[C@@H](CC(C)C)C(=O)N...
# 2                 taxol  CC(=O)O[C@H]1C(=O)[C@]2(C)[C@@H](O)C[C@H]3OC[C...
# 3          camptothecin  CC[C@@]1(O)C(=O)OCC2=C1C=C3N(Cc4cc5ccccc5nc34)...
# 4    Cdk1 inhibitor III             CCOC(=O)c1cnc2oc3ccc(O)cc3c2c1c4ccccc4
# ..                  ...                                                ...
# 108           LY-294002                O=C1C=C(Oc2c1cccc2c3ccccc3)N4CCOCC4
# 109           SB-202190       Oc1ccc(cc1)c2nc(c3ccc(F)cc3)c([nH]2)c4ccncc4
# 110               AZ701  CN(CCOc1cccc2ncnc(Nc3ccc(OCc4ccccn4)c(Cl)c3)c1...
# 111                AZ-K                                                NaN
# 112          raloxifene  Oc1ccc(cc1)c2sc3cc(O)ccc3c2C(=O)c4ccc(OCCN5CCC...
#
# [113 rows x 2 columns]

# %%
# remove rows with NaN values
smiles_df = smiles_df.dropna()
# reset index
smiles_df = smiles_df.reset_index(drop=True)
smiles_list = smiles_df['smiles'].values
smiles_df
# Out:
#                  compound                                             smiles
# 0               leupeptin  CC(C)C[C@H](NC(=O)C)C(=O)N[C@@H](CC(C)C)C(=O)N...
# 1                   taxol  CC(=O)O[C@H]1C(=O)[C@]2(C)[C@@H](O)C[C@H]3OC[C...
# 2            camptothecin  CC[C@@]1(O)C(=O)OCC2=C1C=C3N(Cc4cc5ccccc5nc34)...
# 3      Cdk1 inhibitor III             CCOC(=O)c1cnc2oc3ccc(O)cc3c2c1c4ccccc4
# 4   3,3'-diaminobenzidine                         Nc1ccc(cc1N)c2ccc(N)c(N)c2
# ..                    ...                                                ...
# 93                 UO-126  N\\C(=C(\\C#N)/C(=C(\\N)/Sc1ccccc1N)/C#N)\\Sc2...
# 94              LY-294002                O=C1C=C(Oc2c1cccc2c3ccccc3)N4CCOCC4
# 95              SB-202190       Oc1ccc(cc1)c2nc(c3ccc(F)cc3)c([nH]2)c4ccncc4
# 96                  AZ701  CN(CCOc1cccc2ncnc(Nc3ccc(OCc4ccccn4)c(Cl)c3)c1...
# 97             raloxifene  Oc1ccc(cc1)c2sc3cc(O)ccc3c2C(=O)c4ccc(OCCN5CCC...
#
# [98 rows x 2 columns]

# %%
generator = MakeGenerator(("RDKit2D",))
for name, numpy_type in generator.GetColumns():
    print(f"{name}({numpy_type.__name__})")
# Out:
# RDKit2D_calculated(bool)
# BalabanJ(float64)
# BertzCT(float64)
# Chi0(float64)
# Chi0n(float64)
# Chi0v(float64)
# Chi1(float64)
# Chi1n(float64)
# Chi1v(float64)
# Chi2n(float64)
# Chi2v(float64)
# Chi3n(float64)
# Chi3v(float64)
# Chi4n(float64)
# Chi4v(float64)
# EState_VSA1(float64)
# EState_VSA10(float64)
# EState_VSA11(float64)
# EState_VSA2(float64)
# EState_VSA3(float64)
# EState_VSA4(float64)
# EState_VSA5(float64)
# EState_VSA6(float64)
# EState_VSA7(float64)
# EState_VSA8(float64)
# EState_VSA9(float64)
# ExactMolWt(float64)
# FpDensityMorgan1(float64)
# FpDensityMorgan2(float64)
# FpDensityMorgan3(float64)
# FractionCSP3(float64)
# HallKierAlpha(float64)
# HeavyAtomCount(float64)
# HeavyAtomMolWt(float64)
# Ipc(float64)
# Kappa1(float64)
# Kappa2(float64)
# Kappa3(float64)
# LabuteASA(float64)
# MaxAbsEStateIndex(float64)
# MaxAbsPartialCharge(float64)
# MaxEStateIndex(float64)
# MaxPartialCharge(float64)
# MinAbsEStateIndex(float64)
# MinAbsPartialCharge(float64)
# MinEStateIndex(float64)
# MinPartialCharge(float64)
# MolLogP(float64)
# MolMR(float64)
# MolWt(float64)
# NHOHCount(float64)
# NOCount(float64)
# NumAliphaticCarbocycles(float64)
# NumAliphaticHeterocycles(float64)
# NumAliphaticRings(float64)
# NumAromaticCarbocycles(float64)
# NumAromaticHeterocycles(float64)
# NumAromaticRings(float64)
# NumHAcceptors(float64)
# NumHDonors(float64)
# NumHeteroatoms(float64)
# NumRadicalElectrons(float64)
# NumRotatableBonds(float64)
# NumSaturatedCarbocycles(float64)
# NumSaturatedHeterocycles(float64)
# NumSaturatedRings(float64)
# NumValenceElectrons(float64)
# PEOE_VSA1(float64)
# PEOE_VSA10(float64)
# PEOE_VSA11(float64)
# PEOE_VSA12(float64)
# PEOE_VSA13(float64)
# PEOE_VSA14(float64)
# PEOE_VSA2(float64)
# PEOE_VSA3(float64)
# PEOE_VSA4(float64)
# PEOE_VSA5(float64)
# PEOE_VSA6(float64)
# PEOE_VSA7(float64)
# PEOE_VSA8(float64)
# PEOE_VSA9(float64)
# RingCount(float64)
# SMR_VSA1(float64)
# SMR_VSA10(float64)
# SMR_VSA2(float64)
# SMR_VSA3(float64)
# SMR_VSA4(float64)
# SMR_VSA5(float64)
# SMR_VSA6(float64)
# SMR_VSA7(float64)
# SMR_VSA8(float64)
# SMR_VSA9(float64)
# SlogP_VSA1(float64)
# SlogP_VSA10(float64)
# SlogP_VSA11(float64)
# SlogP_VSA12(float64)
# SlogP_VSA2(float64)
# SlogP_VSA3(float64)
# SlogP_VSA4(float64)
# SlogP_VSA5(float64)
# SlogP_VSA6(float64)
# SlogP_VSA7(float64)
# SlogP_VSA8(float64)
# SlogP_VSA9(float64)
# TPSA(float64)
# VSA_EState1(float64)
# VSA_EState10(float64)
# VSA_EState2(float64)
# VSA_EState3(float64)
# VSA_EState4(float64)
# VSA_EState5(float64)
# VSA_EState6(float64)
# VSA_EState7(float64)
# VSA_EState8(float64)
# VSA_EState9(float64)
# fr_Al_COO(float64)
# fr_Al_OH(float64)
# fr_Al_OH_noTert(float64)
# fr_ArN(float64)
# fr_Ar_COO(float64)
# fr_Ar_N(float64)
# fr_Ar_NH(float64)
# fr_Ar_OH(float64)
# fr_COO(float64)
# fr_COO2(float64)
# fr_C_O(float64)
# fr_C_O_noCOO(float64)
# fr_C_S(float64)
# fr_HOCCN(float64)
# fr_Imine(float64)
# fr_NH0(float64)
# fr_NH1(float64)
# fr_NH2(float64)
# fr_N_O(float64)
# fr_Ndealkylation1(float64)
# fr_Ndealkylation2(float64)
# fr_Nhpyrrole(float64)
# fr_SH(float64)
# fr_aldehyde(float64)
# fr_alkyl_carbamate(float64)
# fr_alkyl_halide(float64)
# fr_allylic_oxid(float64)
# fr_amide(float64)
# fr_amidine(float64)
# fr_aniline(float64)
# fr_aryl_methyl(float64)
# fr_azide(float64)
# fr_azo(float64)
# fr_barbitur(float64)
# fr_benzene(float64)
# fr_benzodiazepine(float64)
# fr_bicyclic(float64)
# fr_diazo(float64)
# fr_dihydropyridine(float64)
# fr_epoxide(float64)
# fr_ester(float64)
# fr_ether(float64)
# fr_furan(float64)
# fr_guanido(float64)
# fr_halogen(float64)
# fr_hdrzine(float64)
# fr_hdrzone(float64)
# fr_imidazole(float64)
# fr_imide(float64)
# fr_isocyan(float64)
# fr_isothiocyan(float64)
# fr_ketone(float64)
# fr_ketone_Topliss(float64)
# fr_lactam(float64)
# fr_lactone(float64)
# fr_methoxy(float64)
# fr_morpholine(float64)
# fr_nitrile(float64)
# fr_nitro(float64)
# fr_nitro_arom(float64)
# fr_nitro_arom_nonortho(float64)
# fr_nitroso(float64)
# fr_oxazole(float64)
# fr_oxime(float64)
# fr_para_hydroxylation(float64)
# fr_phenol(float64)
# fr_phenol_noOrthoHbond(float64)
# fr_phos_acid(float64)
# fr_phos_ester(float64)
# fr_piperdine(float64)
# fr_piperzine(float64)
# fr_priamide(float64)
# fr_prisulfonamd(float64)
# fr_pyridine(float64)
# fr_quatN(float64)
# fr_sulfide(float64)
# fr_sulfonamd(float64)
# fr_sulfone(float64)
# fr_term_acetylene(float64)
# fr_tetrazole(float64)
# fr_thiazole(float64)
# fr_thiocyan(float64)
# fr_thiophene(float64)
# fr_unbrch_alkane(float64)
# fr_urea(float64)
# qed(float64)

# %%
n_jobs = 16
data = Parallel(n_jobs=n_jobs)(delayed(generator.process)(smiles) for smiles in tqdm(smiles_list, position=0, leave=True) )
# Out:
#   0%|          | 0/98 [00:00<?, ?it/s]

# %%
smiles_df
# Out:
#                  compound                                             smiles
# 0               leupeptin  CC(C)C[C@H](NC(=O)C)C(=O)N[C@@H](CC(C)C)C(=O)N...
# 1                   taxol  CC(=O)O[C@H]1C(=O)[C@]2(C)[C@@H](O)C[C@H]3OC[C...
# 2            camptothecin  CC[C@@]1(O)C(=O)OCC2=C1C=C3N(Cc4cc5ccccc5nc34)...
# 3      Cdk1 inhibitor III             CCOC(=O)c1cnc2oc3ccc(O)cc3c2c1c4ccccc4
# 4   3,3'-diaminobenzidine                         Nc1ccc(cc1N)c2ccc(N)c(N)c2
# ..                    ...                                                ...
# 93                 UO-126  N\\C(=C(\\C#N)/C(=C(\\N)/Sc1ccccc1N)/C#N)\\Sc2...
# 94              LY-294002                O=C1C=C(Oc2c1cccc2c3ccccc3)N4CCOCC4
# 95              SB-202190       Oc1ccc(cc1)c2nc(c3ccc(F)cc3)c([nH]2)c4ccncc4
# 96                  AZ701  CN(CCOc1cccc2ncnc(Nc3ccc(OCc4ccccn4)c(Cl)c3)c1...
# 97             raloxifene  Oc1ccc(cc1)c2sc3cc(O)ccc3c2C(=O)c4ccc(OCCN5CCC...
#
# [98 rows x 2 columns]

# %%
embedding = np.ones((smiles_df.shape[0], len(data[1])))
print(embedding.shape)
print(len(data))
for d in range(len(data)):
    if data[d] is not None:
        embedding[d] = data[d]

embedding[1]
# Out:
# (98, 201)
# 98
# array([ 1.00000000e+00,  1.38744766e+00,  2.28034627e+03,  4.49402179e+01,
#         3.52327485e+01,  3.52327485e+01,  2.92722899e+01,  2.04728500e+01,
#         2.04728500e+01,  1.73540403e+01,  1.73540403e+01,  1.34798552e+01,
#         1.34798552e+01,  1.01825405e+01,  1.01825405e+01,  1.12604095e+02,
#         3.92922681e+01,  4.79453718e+00,  3.53008156e+01,  5.56345149e+00,
#         1.38474744e+01,  2.59802085e+01,  9.27102463e+01,  0.00000000e+00,
#         5.31678860e+00,  2.36843148e+01,  8.53330955e+02,  8.22580645e-01,
#         1.40322581e+00,  1.95161290e+00,  4.46808511e-01, -5.74000000e+00,
#         6.20000000e+01,  8.02510000e+02,  1.95363426e+13,  4.43203576e+01,
#         1.65128455e+01,  7.29440771e+00,  3.57885407e+02,  1.54837950e+01,
#         4.55736924e-01,  1.54837950e+01,  3.38014233e-01,  2.88534398e-03,
#         3.38014233e-01, -2.39095815e+00, -4.55736924e-01,  3.73570000e+00,
#         2.17690100e+02,  8.53918000e+02,  4.00000000e+00,  1.50000000e+01,
#         3.00000000e+00,  1.00000000e+00,  4.00000000e+00,  3.00000000e+00,
#         0.00000000e+00,  3.00000000e+00,  1.40000000e+01,  4.00000000e+00,
#         1.50000000e+01,  0.00000000e+00,  1.00000000e+01,  2.00000000e+00,
#         1.00000000e+00,  3.00000000e+00,  3.28000000e+02,  4.43206856e+01,
#         2.39129500e+01,  2.35922285e+01,  0.00000000e+00,  5.90717973e+00,
#         2.38772212e+01,  1.91781487e+01,  9.58907437e+00,  0.00000000e+00,
#         0.00000000e+00,  8.05775122e+01,  5.48226032e+01,  3.76675596e+01,
#         3.56490372e+01,  7.00000000e+00,  6.77711201e+01,  3.55676458e+01,
#         0.00000000e+00,  5.31678860e+00,  1.67478870e+01,  1.08251807e+02,
#         6.60688196e+00,  1.18832070e+02,  0.00000000e+00,  0.00000000e+00,
#         5.31678860e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         1.05320010e+02,  4.28624635e+01,  1.67478870e+01,  8.67053361e+01,
#         1.02141715e+02,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         2.21290000e+02,  3.02723829e+01,  0.00000000e+00,  8.34533118e+01,
#         4.02339524e+01, -7.01908503e+00, -6.84115883e+00,  2.29377116e+01,
#        -1.05115569e+01,  7.97444194e+00,  0.00000000e+00,  0.00000000e+00,
#         3.00000000e+00,  2.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  6.00000000e+00,  6.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  3.00000000e+00,  0.00000000e+00,  5.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  4.00000000e+00,
#         5.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         1.29786194e-01])

# %%
import pandas as pd

df = pd.DataFrame(data=embedding,
                  index=smiles_df['compound'],
                  columns=[f'latent_{i}' for i in range(embedding.shape[1])]) 
df
# Out:
#                        latent_0  latent_1     latent_2   latent_3   latent_4  \
# compound
# leupeptin                   1.0  5.060057   593.845766  23.267220  18.709979
# taxol                       1.0  1.387448  2280.346270  44.940218  35.232749
# camptothecin                1.0  1.813414  1164.420305  18.051677  14.151808
# Cdk1 inhibitor III          1.0  2.138325  1083.202781  17.388541  13.522431
# 3,3'-diaminobenzidine       1.0  2.502080   485.037124  11.706742   8.773503
# ...                         ...       ...          ...        ...        ...
# UO-126                      1.0  2.415200   886.631991  19.104084  13.639127
# LY-294002                   1.0  1.910040   880.005356  15.648054  12.696538
# SB-202190                   1.0  1.885294   993.562933  17.225404  13.147808
# AZ701                       1.0  1.493865  1300.537790  24.622745  19.018057
# raloxifene                  1.0  1.388562  1288.742785  23.492989  18.866986
#
#                         latent_5   latent_6   latent_7   latent_8   latent_9  \
# compound
# leupeptin              18.709979  13.954504  10.367655  10.367655   8.307227
# taxol                  35.232749  29.272290  20.472850  20.472850  17.354040
# camptothecin           14.151808  12.525024   8.585127   8.585127   6.791866
# Cdk1 inhibitor III     13.522431  12.185872   7.955084   7.955084   5.596047
# 3,3'-diaminobenzidine   8.773503   7.575387   4.880768   4.880768   3.687393
# ...                          ...        ...        ...        ...        ...
# UO-126                 15.272120  12.472764   7.323111   8.956104   4.981885
# LY-294002              12.696538  11.326500   7.777836   7.777836   5.596592
# SB-202190              13.147808  12.203510   7.762952   7.762952   5.598673
# AZ701                  19.773986  17.046045  10.855231  11.233195   7.574371
# raloxifene             19.683483  16.580520  11.631837  12.448333   8.637787
#
#                        ...  latent_191  latent_192  latent_193  latent_194  \
# compound               ...
# leupeptin              ...         0.0         0.0         0.0         0.0
# taxol                  ...         0.0         0.0         0.0         0.0
# camptothecin           ...         0.0         0.0         0.0         0.0
# Cdk1 inhibitor III     ...         0.0         0.0         0.0         0.0
# 3,3'-diaminobenzidine  ...         0.0         0.0         0.0         0.0
# ...                    ...         ...         ...         ...         ...
# UO-126                 ...         0.0         0.0         0.0         0.0
# LY-294002              ...         0.0         0.0         0.0         0.0
# SB-202190              ...         0.0         0.0         0.0         0.0
# AZ701                  ...         0.0         0.0         0.0         0.0
# raloxifene             ...         0.0         0.0         0.0         0.0
#
#                        latent_195  latent_196  latent_197  latent_198  \
# compound
# leupeptin                     0.0         0.0         0.0         1.0
# taxol                         0.0         0.0         0.0         0.0
# camptothecin                  0.0         0.0         0.0         0.0
# Cdk1 inhibitor III            0.0         0.0         0.0         0.0
# 3,3'-diaminobenzidine         0.0         0.0         0.0         0.0
# ...                           ...         ...         ...         ...
# UO-126                        0.0         0.0         0.0         0.0
# LY-294002                     0.0         0.0         0.0         0.0
# SB-202190                     0.0         0.0         0.0         0.0
# AZ701                         0.0         0.0         0.0         0.0
# raloxifene                    0.0         0.0         1.0         0.0
#
#                        latent_199  latent_200
# compound
# leupeptin                     0.0    0.099043
# taxol                         0.0    0.129786
# camptothecin                  0.0    0.532764
# Cdk1 inhibitor III            0.0    0.557654
# 3,3'-diaminobenzidine         0.0    0.541933
# ...                           ...         ...
# UO-126                        0.0    0.267079
# LY-294002                     0.0    0.728379
# SB-202190                     0.0    0.574239
# AZ701                         0.0    0.342808
# raloxifene                    0.0    0.318664
#
# [98 rows x 201 columns]

# %%
# Drop first feature from generator (RDKit2D_calculated)
df.drop(columns=['latent_0'], inplace=True)

# Drop columns with 0 standard deviation
threshold = 0.001
columns=[f'latent_{idx+1}' for idx in np.where(df.std() <= threshold)[0]]
print(f'Deleting columns with std<={threshold}: {columns}')
df.drop(columns=[f'latent_{idx+1}' for idx in np.where(df.std() <= threshold)[0]], inplace=True)
# Out:
# Deleting columns with std<=0.001: ['latent_61', 'latent_90', 'latent_103', 'latent_119', 'latent_137', 'latent_143', 'latent_146', 'latent_147', 'latent_148', 'latent_150', 'latent_152', 'latent_153', 'latent_160', 'latent_161', 'latent_164', 'latent_165', 'latent_168', 'latent_176', 'latent_177', 'latent_178', 'latent_182', 'latent_183', 'latent_187', 'latent_189', 'latent_193', 'latent_194', 'latent_196']

# %%
df
# Out:
#                        latent_1     latent_2   latent_3   latent_4   latent_5  \
# compound
# leupeptin              5.060057   593.845766  23.267220  18.709979  18.709979
# taxol                  1.387448  2280.346270  44.940218  35.232749  35.232749
# camptothecin           1.813414  1164.420305  18.051677  14.151808  14.151808
# Cdk1 inhibitor III     2.138325  1083.202781  17.388541  13.522431  13.522431
# 3,3'-diaminobenzidine  2.502080   485.037124  11.706742   8.773503   8.773503
# ...                         ...          ...        ...        ...        ...
# UO-126                 2.415200   886.631991  19.104084  13.639127  15.272120
# LY-294002              1.910040   880.005356  15.648054  12.696538  12.696538
# SB-202190              1.885294   993.562933  17.225404  13.147808  13.147808
# AZ701                  1.493865  1300.537790  24.622745  19.018057  19.773986
# raloxifene             1.388562  1288.742785  23.492989  18.866986  19.683483
#
#                         latent_6   latent_7   latent_8   latent_9  latent_10  \
# compound
# leupeptin              13.954504  10.367655  10.367655   8.307227   8.307227
# taxol                  29.272290  20.472850  20.472850  17.354040  17.354040
# camptothecin           12.525024   8.585127   8.585127   6.791866   6.791866
# Cdk1 inhibitor III     12.185872   7.955084   7.955084   5.596047   5.596047
# 3,3'-diaminobenzidine   7.575387   4.880768   4.880768   3.687393   3.687393
# ...                          ...        ...        ...        ...        ...
# UO-126                 12.472764   7.323111   8.956104   4.981885   7.149439
# LY-294002              11.326500   7.777836   7.777836   5.596592   5.596592
# SB-202190              12.203510   7.762952   7.762952   5.598673   5.598673
# AZ701                  17.046045  10.855231  11.233195   7.574371   7.981571
# raloxifene             16.580520  11.631837  12.448333   8.637787   9.689986
#
#                        ...  latent_186  latent_188  latent_190  latent_191  \
# compound               ...
# leupeptin              ...         0.0         0.0         0.0         0.0
# taxol                  ...         0.0         0.0         0.0         0.0
# camptothecin           ...         0.0         2.0         0.0         0.0
# Cdk1 inhibitor III     ...         0.0         1.0         0.0         0.0
# 3,3'-diaminobenzidine  ...         0.0         0.0         0.0         0.0
# ...                    ...         ...         ...         ...         ...
# UO-126                 ...         0.0         0.0         2.0         0.0
# LY-294002              ...         0.0         0.0         0.0         0.0
# SB-202190              ...         0.0         1.0         0.0         0.0
# AZ701                  ...         0.0         1.0         0.0         0.0
# raloxifene             ...         0.0         0.0         0.0         0.0
#
#                        latent_192  latent_195  latent_197  latent_198  \
# compound
# leupeptin                     0.0         0.0         0.0         1.0
# taxol                         0.0         0.0         0.0         0.0
# camptothecin                  0.0         0.0         0.0         0.0
# Cdk1 inhibitor III            0.0         0.0         0.0         0.0
# 3,3'-diaminobenzidine         0.0         0.0         0.0         0.0
# ...                           ...         ...         ...         ...
# UO-126                        0.0         0.0         0.0         0.0
# LY-294002                     0.0         0.0         0.0         0.0
# SB-202190                     0.0         0.0         0.0         0.0
# AZ701                         0.0         0.0         0.0         0.0
# raloxifene                    0.0         0.0         1.0         0.0
#
#                        latent_199  latent_200
# compound
# leupeptin                     0.0    0.099043
# taxol                         0.0    0.129786
# camptothecin                  0.0    0.532764
# Cdk1 inhibitor III            0.0    0.557654
# 3,3'-diaminobenzidine         0.0    0.541933
# ...                           ...         ...
# UO-126                        0.0    0.267079
# LY-294002                     0.0    0.728379
# SB-202190                     0.0    0.574239
# AZ701                         0.0    0.342808
# raloxifene                    0.0    0.318664
#
# [98 rows x 173 columns]

# %%
normalized_df=(df-df.mean())/df.std()

# %%
normalized_df.head()
refined_index = list()
for index in normalized_df.index.tolist():
    refined_index.append(index.lower().replace(' ', '-').replace('/', '-').replace('(', '-').replace(')', '-').replace('\'', ''))
normalized_df.index = refined_index

# %%
normalized_df.fillna(0, inplace=True)

# %%
# save normalized_df to csv
normalized_df.to_csv('required_file/perturbation_embedding_bbbc021.csv')
